# %%
#Importando librerias

import numpy as np
import pandas as pd

# %%
#Importando archivo csv. El mismo contiene filas con errores, donde se encuentran mas valores de los que corresponde.
#Se decide eliminarlas con el parametro error_bad_lines

data_books = pd.read_csv(r"C:\Users\estefania.rodriguez\Desktop\Datos\books.csv", error_bad_lines=False)
# Out:
# C:\Users\estefania.rodriguez\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# b'Skipping line 4012: expected 10 fields, saw 11\nSkipping line 5688: expected 10 fields, saw 11\nSkipping line 7056: expected 10 fields, saw 11\nSkipping line 10601: expected 10 fields, saw 11\nSkipping line 10668: expected 10 fields, saw 11\n'

# %%
data_books
# Out:
#       bookID                                              title  \
# 0          1  Harry Potter and the Half-Blood Prince (Harry ...
# 1          2  Harry Potter and the Order of the Phoenix (Har...
# 2          3  Harry Potter and the Sorcerer's Stone (Harry P...
# 3          4  Harry Potter and the Chamber of Secrets (Harry...
# 4          5  Harry Potter and the Prisoner of Azkaban (Harr...
# ...      ...                                                ...
# 13709  47699                                     M Is for Magic
# 13710  47700                                       Black Orchid
# 13711  47701                        InterWorld (InterWorld  #1)
# 13712  47708                                The Faeries' Oracle
# 13713  47709                      The World of The Dark Crystal
#
#                              authors  average_rating        isbn  \
# 0         J.K. Rowling-Mary GrandPré            4.56  0439785960
# ...

# %%
data_books.columns = ['IdLibro','Título','Autor','Puntuación','ISBN10','ISBN13','Idioma','# Páginas','Puntuación Total','TotalVistas']

# %%
data_books
# Out:
#       IdLibro                                             Título  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           3  Harry Potter and the Sorcerer's Stone (Harry P...
# 3           4  Harry Potter and the Chamber of Secrets (Harry...
# 4           5  Harry Potter and the Prisoner of Azkaban (Harr...
# ...       ...                                                ...
# 13709   47699                                     M Is for Magic
# 13710   47700                                       Black Orchid
# 13711   47701                        InterWorld (InterWorld  #1)
# 13712   47708                                The Faeries' Oracle
# 13713   47709                      The World of The Dark Crystal
#
#                                Autor  Puntuación      ISBN10        ISBN13  \
# 0         J.K. Rowling-Mary GrandPré        4.56  0439785960  9.780440e+12
# ...

# %%
data_books = data_books.set_index('IdLibro')
data_books
# Out:
#                                                     Título  \
# IdLibro
# 1        Harry Potter and the Half-Blood Prince (Harry ...
# 2        Harry Potter and the Order of the Phoenix (Har...
# 3        Harry Potter and the Sorcerer's Stone (Harry P...
# 4        Harry Potter and the Chamber of Secrets (Harry...
# 5        Harry Potter and the Prisoner of Azkaban (Harr...
# ...                                                    ...
# 47699                                       M Is for Magic
# 47700                                         Black Orchid
# 47701                          InterWorld (InterWorld  #1)
# 47708                                  The Faeries' Oracle
# 47709                        The World of The Dark Crystal
#
#                                  Autor  Puntuación      ISBN10        ISBN13  \
# IdLibro
# 1           J.K. Rowling-Mary GrandPré        4.56  0439785960  9.780440e+12
# 2           J.K. Rowling-Mary GrandPré        4.49  0439358078  9.780439e+12
# ...

# %%
data_books.head(5)
# Out:
#                                                     Título  \
# IdLibro
# 1        Harry Potter and the Half-Blood Prince (Harry ...
# 2        Harry Potter and the Order of the Phoenix (Har...
# 3        Harry Potter and the Sorcerer's Stone (Harry P...
# 4        Harry Potter and the Chamber of Secrets (Harry...
# 5        Harry Potter and the Prisoner of Azkaban (Harr...
#
#                               Autor  Puntuación      ISBN10        ISBN13  \
# IdLibro
# 1        J.K. Rowling-Mary GrandPré        4.56  0439785960  9.780440e+12
# 2        J.K. Rowling-Mary GrandPré        4.49  0439358078  9.780439e+12
# 3        J.K. Rowling-Mary GrandPré        4.47  0439554934  9.780440e+12
# 4                      J.K. Rowling        4.41  0439554896  9.780440e+12
# 5        J.K. Rowling-Mary GrandPré        4.55  043965548X  9.780440e+12
#
#         Idioma  # Páginas  Puntuación Total TotalVistas
# IdLibro
# 1          eng      652.0         1944099.0    26249;;;
# ...

# %%
data_books['TotalVistas'] = data_books['TotalVistas'].replace({';;;':''}, regex=True)
data_books.head(5)
# Out:
#                                                     Título  \
# IdLibro
# 1        Harry Potter and the Half-Blood Prince (Harry ...
# 2        Harry Potter and the Order of the Phoenix (Har...
# 3        Harry Potter and the Sorcerer's Stone (Harry P...
# 4        Harry Potter and the Chamber of Secrets (Harry...
# 5        Harry Potter and the Prisoner of Azkaban (Harr...
#
#                               Autor  Puntuación      ISBN10        ISBN13  \
# IdLibro
# 1        J.K. Rowling-Mary GrandPré        4.56  0439785960  9.780440e+12
# 2        J.K. Rowling-Mary GrandPré        4.49  0439358078  9.780439e+12
# 3        J.K. Rowling-Mary GrandPré        4.47  0439554934  9.780440e+12
# 4                      J.K. Rowling        4.41  0439554896  9.780440e+12
# 5        J.K. Rowling-Mary GrandPré        4.55  043965548X  9.780440e+12
#
#         Idioma  # Páginas  Puntuación Total TotalVistas
# IdLibro
# 1          eng      652.0         1944099.0       26249
# ...

# %%
#Se intenta pasar a int las siguientes columnas. Ambas tenian valores na, por lo tanto primero se reemplazara por -1 y luego a int

data_books['Puntuación Total'] = data_books['Puntuación Total'].astype(int)
data_books['# Páginas'] = data_books['# Páginas'].astype(int)
data_books['Puntuación'] = data_books['Puntuación Total'].astype(int)
data_books.head(5)
# Out:
#          Título  Autor  Puntuación  ISBN10        ISBN13 Idioma  # Páginas  \
# IdLibro
# 1          3707   3017     1944099    4964  9.780440e+12  26249        652
# 2          3708   3017     1996446    4881  9.780439e+12  27613        870
# 3          3711   3017     5629932    4923  9.780440e+12  70390        320
# 4          3705   3011        6267    4922  9.780440e+12    272        352
# 5          3710   3017     2149872    4944  9.780440e+12  33964        435
#
#          Puntuación Total TotalVistas
# IdLibro
# 1                 1944099       26249
# 2                 1996446       27613
# 3                 5629932       70390
# 4                    6267         272
# 5                 2149872       33964

# %%
data_books['Puntuación Total'] = data_books['Puntuación Total'].fillna(0)
data_books['# Páginas'] = data_books['# Páginas'].fillna(0)
data_books
# Out:
#                                                     Título  \
# IdLibro
# 1        Harry Potter and the Half-Blood Prince (Harry ...
# 2        Harry Potter and the Order of the Phoenix (Har...
# 3        Harry Potter and the Sorcerer's Stone (Harry P...
# 4        Harry Potter and the Chamber of Secrets (Harry...
# 5        Harry Potter and the Prisoner of Azkaban (Harr...
# ...                                                    ...
# 47699                                       M Is for Magic
# 47700                                         Black Orchid
# 47701                          InterWorld (InterWorld  #1)
# 47708                                  The Faeries' Oracle
# 47709                        The World of The Dark Crystal
#
#                                  Autor  Puntuación      ISBN10        ISBN13  \
# IdLibro
# 1           J.K. Rowling-Mary GrandPré        4.56  0439785960  9.780440e+12
# 2           J.K. Rowling-Mary GrandPré        4.49  0439358078  9.780439e+12
# ...

# %%
data_books['Puntuación Total'] = data_books['Puntuación Total'].astype(int)
data_books['# Páginas'] = data_books['# Páginas'].astype(int)
data_books.head(5)
# Out:
#                                                     Título  \
# IdLibro
# 1        Harry Potter and the Half-Blood Prince (Harry ...
# 2        Harry Potter and the Order of the Phoenix (Har...
# 3        Harry Potter and the Sorcerer's Stone (Harry P...
# 4        Harry Potter and the Chamber of Secrets (Harry...
# 5        Harry Potter and the Prisoner of Azkaban (Harr...
#
#                               Autor  Puntuación      ISBN10        ISBN13  \
# IdLibro
# 1        J.K. Rowling-Mary GrandPré        4.56  0439785960  9.780440e+12
# 2        J.K. Rowling-Mary GrandPré        4.49  0439358078  9.780439e+12
# 3        J.K. Rowling-Mary GrandPré        4.47  0439554934  9.780440e+12
# 4                      J.K. Rowling        4.41  0439554896  9.780440e+12
# 5        J.K. Rowling-Mary GrandPré        4.55  043965548X  9.780440e+12
#
#         Idioma  # Páginas  Puntuación Total TotalVistas
# IdLibro
# 1          eng        652           1944099       26249
# ...

# %%
#Cantidad de vistas por libro en todo el mundo
total_views_word = data_books.groupby(['Título'])['TotalVistas'].agg(['sum', 'count'])
total_views_word
# Out:
#                                                                          sum  \
# Título
#   said the shotgun to the head.                                          216
# $30 Film School: How to Write  Direct  Produce ...                         4
# 'Salem's Lot                                        504551214533655133575320
# 'Tis A Memoir (Frank McCourt  #2)                                       1611
# 1 000 Places to See Before You Die                                       429
# ...                                                                      ...
# 鋼之鍊金術師 6                                                                   0
# 鋼之鍊金術師 7                                                                   0
# 鋼之鍊金術師 9                                                                   0
# 魔戒二部曲：雙城奇謀                                                                 0
# 魔戒首部曲：魔戒現身                                                                 0
#
# ...

# %%
#Cantidad de vistas por libro por idioma
total_views_word = data_books.groupby(['Título','Idioma'])['TotalVistas'].agg(['sum', 'count'])
total_views_word
# Out:
#                                                                              sum  \
# Título                                             Idioma
#   said the shotgun to the head.                    en-US                     216
# $30 Film School: How to Write  Direct  Produce ... eng                         4
# 'Salem's Lot                                       en-US                     335
#                                                    eng     504551214565513357320
# 'Tis A Memoir (Frank McCourt  #2)                  eng                      1611
# ...                                                                          ...
# 鋼之鍊金術師 6                                           zho                         0
# 鋼之鍊金術師 7                                           zho                         0
# 鋼之鍊金術師 9                                           zho                         0
# 魔戒二部曲：雙城奇謀                                         zho                         0
# ...

# %%
#Puntuacion total por libro 
total_book_puntuacion = data_books.groupby(['Título'])['Puntuación Total'].agg(['sum'])
total_book_puntuacion
# Out:
#                                                        sum
# Título
#   said the shotgun to the head.                       2687
# $30 Film School: How to Write  Direct  Produce ...      29
# 'Salem's Lot                                        352891
# 'Tis A Memoir (Frank McCourt  #2)                    44179
# 1 000 Places to See Before You Die                   35589
# ...                                                    ...
# 鋼之鍊金術師 6                                                 5
# 鋼之鍊金術師 7                                                 5
# 鋼之鍊金術師 9                                                 4
# 魔戒二部曲：雙城奇謀                                              20
# 魔戒首部曲：魔戒現身                                              22
#
# [12394 rows x 1 columns]

# %%
#Cantidad de libros por autor
book_author = data_books.groupby(['Autor'])['Título'].agg(['count'])
book_author
# Out:
#                                                     count
# Autor
# A.B. Yehoshua-Hillel Halkin                             2
# A.D.P. Briggs-Leo Tolstoy-Fyodor Dostoyevsky            1
# A.E. Cunningham-Harlan Ellison-Charles F. Mille...      1
# A.J. Jacobs                                             1
# A.M. Homes                                              2
# ...                                                   ...
# Émile Zola-Henri Mitterand                              1
# Émile Zola-Robert Lethbridge-Elinor Dorday              1
# Émile Zola-Robin Buss-Brian  Nelson                     1
# Émile Zola-Roger Pearson                                2
# Éric-Emmanuel Schmitt                                   2
#
# [7580 rows x 1 columns]

# %%
#Graficas
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Top 7 de lenguajes
data_books['Idioma'].value_counts().head(7).plot(kind = 'pie').legend()

# %%
#10 libros mas populares
popular_books = data_books.nlargest(10, ['Puntuación Total']).set_index('Título')['Puntuación Total']
sns.barplot(popular_books, popular_books.index)
# Out:
# <AxesSubplot:xlabel='Puntuación Total', ylabel='Título'>

# %%
#Preprocesamiento de datos

from sklearn import preprocessing

#Tranformo las columnas categoricas en numericos

le = preprocessing.LabelEncoder()
data_books['Título'] = le.fit_transform(data_books['Título'])

data_books['Autor'] = le.fit_transform(data_books['Autor'])

data_books['Idioma'] = le.fit_transform(data_books['Idioma'])

data_books['ISBN10'] = le.fit_transform(data_books['ISBN10'])

# %%
data_books
# Out:
#          Título  Autor  Puntuación  ISBN10        ISBN13  Idioma  # Páginas  \
# IdLibro
# 1          3707   3017        4.56    4964  9.780440e+12       7        652
# 2          3708   3017        4.49    4881  9.780439e+12       7        870
# 3          3711   3017        4.47    4923  9.780440e+12       7        320
# 4          3705   3011        4.41    4922  9.780440e+12       7        352
# 5          3710   3017        4.55    4944  9.780440e+12       7        435
# ...         ...    ...         ...     ...           ...     ...        ...
# 47699      5187   5241        3.82     825  9.780061e+12       7        260
# 47700      1197   5228        3.72   10213  9.780930e+12       7        160
# 47701      4264   5234        3.53     840  9.780061e+12       6        239
# 47708      9022    807        4.43    8017  9.780743e+12       7        224
# 47709     11170    806        4.29   12395  9.781862e+12       7        132
#
#          Puntuación Total TotalVistas
# ...

# %%
#Regresion lineal

#Defino cuales campos me van a ayudar a predecir la puntuacion (x), y ademas la variable que debo predecir (y)
x = data_books.drop(['Puntuación', 'Idioma'], axis = 1)
y = data_books['Puntuación']


data_books
# Out:
#                                                     Título  Autor  Puntuación  \
# IdLibro
# 9,Unauthorized Harry Potter Book Seven News: "H...   12394   7580         0.0
# 51,Hatchet: A Guide for Using "Hatchet" in the ...   12394   7580         0.0
# 177,A Wrinkle in Time: A Guide for Using "A Wri...   12394   7580         0.0
# 534                                                  11861   1962         1.0
# 681,Natural Cures "They" Don't Want You to Know...   12394   7580         0.0
# ...                                                    ...    ...         ...
# 47008                                                 5590   4290         1.0
# 47050                                                11726   7123         0.0
# 47295                                                 4139   5468         0.0
# 47408                                                11789   3511         1.0
# 47551                                                 4738   6505         0.0
#
# ...

# %%
#Divido el 80% de los datos para entrenar y el 20% para predecir (test_size)

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)

# %%
#identifique datos que quedaron mal

data_books['TotalVistas'] = data_books['TotalVistas'].replace({';;':''}, regex=True)
data_books['Puntuación'] = data_books['Puntuación'].replace({';;':''}, regex=True)
data_books['Idioma'] = data_books['Idioma'].replace({';;':''}, regex=True)

# %%
#Intento filtrar por las columnas donde segun el error hay un dato erroneo
data_filter = data_books[data_books['Idioma'] == '751;;']
data_filter
# Out:
# Empty DataFrame
# Columns: [Título, Autor, Puntuación, ISBN10, ISBN13, Idioma, # Páginas, Puntuación Total, TotalVistas]
# Index: []

# %%
#Busco columna por columna: #Título	Autor	Puntuación	ISBN10	ISBN13	Idioma	# Páginas	Puntuación Total	TotalVistas
data_filter = data_books[data_books['Título'] == '755;;']
data_filter

# se identifica el dato en la columna TotalVistas
# Out:
# Empty DataFrame
# Columns: [Título, Autor, Puntuación, ISBN10, ISBN13, Idioma, # Páginas, Puntuación Total, TotalVistas]
# Index: []

# %%
#Limpieza
data_books['TotalVistas'] = data_books['TotalVistas'].replace({';;':''}, regex=True)

# %%
#Se reintenta
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ESTEFA~1.ROD\AppData\Local\Temp/ipykernel_4816/841234438.py in <module>
#       3
#       4 lr = LinearRegression()
# ----> 5 lr.fit(X_train, y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     516         accept_sparse = False if self.positive else ['csr', 'csc', 'coo']
#     517
# --> 518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
#     519                                    y_numeric=True, multi_output=True)
#     520
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
# ...

# %%
#vuelve el mismo error. Se procede a limpiar todas las columnas nvte
#Título	Autor	Puntuación	ISBN10	ISBN13	Idioma	# Páginas	Puntuación Total	TotalVistas
data_books['Título'] = data_books['Título'].replace({';;':''}, regex=True)
data_books['Autor'] = data_books['Autor'].replace({';;':''}, regex=True)
data_books['Puntuación'] = data_books['Puntuación'].replace({';;':''}, regex=True)
data_books['ISBN10'] = data_books['ISBN10'].replace({';;':''}, regex=True)
data_books['Idioma'] = data_books['Idioma'].replace({';;':''}, regex=True)
data_books['# Páginas'] = data_books['# Páginas'].replace({';;':''}, regex=True)
data_books['Puntuación Total'] = data_books['Puntuación Total'].replace({';;':''}, regex=True)
data_books['TotalVistas'] = data_books['TotalVistas'].replace({';;':''}, regex=True)

# %%
#Se reintenta
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

# %%
#vuelve el mismo error. Se procede a limpiar todas las columnas nvte
#Título	Autor	Puntuación	ISBN10	ISBN13	Idioma	# Páginas	Puntuación Total	TotalVistas
data_books['Título'] = data_books['Título'].replace({';':''}, regex=True)
data_books['Autor'] = data_books['Autor'].replace({';':''}, regex=True)
data_books['Puntuación'] = data_books['Puntuación'].replace({';;':''}, regex=True)
data_books['ISBN10'] = data_books['ISBN10'].replace({';':''}, regex=True)
data_books['Idioma'] = data_books['Idioma'].replace({';':''}, regex=True)
data_books['# Páginas'] = data_books['# Páginas'].replace({';;':''}, regex=True)
data_books['Puntuación Total'] = data_books['Puntuación Total'].replace({';':''}, regex=True)
data_books['TotalVistas'] = data_books['TotalVistas'].replace({';':''}, regex=True)

# %%
data_books.dropna()
# Out:
#          Título  Autor  Puntuación   ISBN10        ISBN13 Idioma  # Páginas  \
# IdLibro
# 534       11861   1962         1.0    273.0  9.780060e+12      0        216
# 787        9890   6004         1.0  12205.0  9.781844e+12      0        363
# 797        5058   4390         0.0  13260.0  9.788408e+12      0        480
# 799        6278   4386         0.0  12087.0  9.781741e+12      0        295
# 1239       7265   6138         1.0   2949.0  9.780317e+12      0        400
# ...         ...    ...         ...      ...           ...    ...        ...
# 47008      5590   4290         1.0  12757.0  9.782229e+12      0        410
# 47050     11726   7123         0.0  12752.0  9.782226e+12      0        464
# 47295      4139   5468         0.0  13540.0  9.788871e+12      0         94
# 47408     11789   3511         1.0  12844.0  9.782710e+12      0        380
# 47551      4738   6505         0.0  10400.0  9.780978e+12      0         64
#
#          Puntuación Total  TotalVistas
# ...

# %%
data_books.notna()
# Out:
#          Título  Autor  Puntuación  ISBN10  ISBN13  Idioma  # Páginas  \
# IdLibro
# 1          True   True        True    True    True    True       True
# 2          True   True        True    True    True    True       True
# 3          True   True        True    True    True    True       True
# 4          True   True        True    True    True    True       True
# 5          True   True        True    True    True    True       True
# ...         ...    ...         ...     ...     ...     ...        ...
# 47699      True   True        True    True    True    True       True
# 47700      True   True        True    True    True    True       True
# 47701      True   True        True    True    True    True       True
# 47708      True   True        True    True    True    True       True
# 47709      True   True        True    True    True    True       True
#
#          Puntuación Total  TotalVistas
# IdLibro
# 1                    True         True
# ...

# %%
#Elimino valores atipicos
sns.boxplot(x=data_books['Puntuación'])
# Out:
# <AxesSubplot:xlabel='Puntuación'>

# %%
data_books = data_books.drop(data_books.index[data_books['Puntuación'] >= 2])

# %%
data_books['Puntuación'] = data_books['Puntuación'].astype(float, errors = 'raise')
data_books['ISBN10'] = data_books['ISBN10'].astype(float, errors = 'raise')
data_books['Puntuación Total'] = data_books['Puntuación Total'].astype(float, errors = 'raise')
data_books['TotalVistas'] = data_books['TotalVistas'].astype(float, errors = 'raise')

# %%
data_books
# Out:
#                                                     Título  Autor  Puntuación  \
# IdLibro
# 9,Unauthorized Harry Potter Book Seven News: "H...   12394   7580         0.0
# 51,Hatchet: A Guide for Using "Hatchet" in the ...   12394   7580         0.0
# 177,A Wrinkle in Time: A Guide for Using "A Wri...   12394   7580         0.0
# 534                                                  11861   1962         1.0
# 681,Natural Cures "They" Don't Want You to Know...   12394   7580         0.0
# ...                                                    ...    ...         ...
# 47008                                                 5590   4290         1.0
# 47050                                                11726   7123         0.0
# 47295                                                 4139   5468         0.0
# 47408                                                11789   3511         1.0
# 47551                                                 4738   6505         0.0
#
# ...

# %%
lr = LinearRegression()

#para que aprenda el modelo
lr.fit(X_train, y_train)

#se obtiene la prediccion usando el modelo entrenado y como parametro el set de datos de prueba
prediccion = lr.predict(X_test)

#se muestra la prediccion del modelo
pred = pd.DataFrame({'SetActual': y_test.tolist(), 'SetPredecido': predictions.tolist()}).head(25)
pred.head(10)
